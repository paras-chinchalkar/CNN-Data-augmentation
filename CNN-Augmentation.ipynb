# %%
#openCV type ka behaviour show karenge ye  upar waale codes
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
img=image.load_img('cat.972.jpg',target_size=(200,200)) #Desirved Size bata rahe hain apan

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
datagen=ImageDataGenerator(
    rotation_range=30,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.2,
    height_shift_range=0.2
    
    
)

# %%
img=image.img_to_array(img)

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
input_batch=img.reshape(1,200,200,3)

# %%
i=0
for output in datagen.flow(input_batch,batch_size=1,save_to_dir='aug'):
    i=i+1
    if i==10:
        break

# %%
input_batch.shape
# Out:
# (1, 200, 200, 3)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
batch_size=16
train_datagen=ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range =0.2,
    horizontal_flip=True
)

test_datagen=ImageDataGenerator(rescale=1./255)

train_generator=train_datagen.flow_from_directory(
    'aug',
    target_size=(150,150),
    batch_size=batch_size,
    class_mode='binary'
)
validatio_generator=test_datagen.flow_from_directory(
    'aug',
    target_size=(150,150),
    batch_size=batch_size,
    class_mode='binary'
)
# Out:
# Found 2 images belonging to 1 classes.
# Found 2 images belonging to 1 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D
from keras.layers import Activation,Dropout,Flatten,Activation,Dense

# %%
model=Sequential()

# %%
model=add(Conv2D(32,(3,3),input_shape))
